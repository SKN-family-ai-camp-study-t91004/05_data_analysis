# %% [markdown]
# # [4] Numpy: 통계

# %% [markdown]
# ### [실습 1] 중심 경향 및 산포 측도 계산
#
#
# 아래 배열에서 평균, 중앙값, 최빈값, 분산, 표준편차, 범위를 계산하세요.
#
#
# ```python
# 	arr = np.array([10, 20, 30, 30, 40, 50, 60])
# ```

# %%
import numpy as np
arr = np.array([10, 20, 30, 30, 40, 50, 60])
print(np.mean(arr))
print(np.median(arr))

values, counts = np.unique(arr, return_counts=True)
print(values[np.argmax(counts)])

print(np.var(arr))
print(np.std(arr))
print(np.max(arr) - np.min(arr))
# Out:
# 34.285714285714285
# 30.0
# 30
# 253.06122448979593
# 15.90789817951435
# 50

# %% [markdown]
# ### [실습 2] 정규분포와 균등분포의 난수 생성
#
#
# 정규분포와 균등분포에서 각각 난수를 생성하여, 평균과 표준편차를 계산하세요.
#
# 1. 평균 0, 표준편차 1인 정규분포 난수 1000개 생성
# 2. 0과 1 사이의 균등분포 난수 1000개 생성

# %%
arr = np.random.randn(1000)
print(np.mean(arr))
print(np.std(arr))

arr2 = np.random.rand(0,1,1000)
print(np.mean(arr2))
print(np.std(arr2))
# Out:
# 0.00670349419267723
# 0.9984991990953108
# nan
# nan
# C:\Users\t9100\miniforge3\envs\pystudy_env\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\t9100\miniforge3\envs\pystudy_env\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\t9100\miniforge3\envs\pystudy_env\Lib\site-packages\numpy\_core\_methods.py:219: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\t9100\miniforge3\envs\pystudy_env\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# C:\Users\t9100\miniforge3\envs\pystudy_env\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### [실습 3] 평균 성적 구하기
#
#
# 아래와 같이 학생별 과목 성적 데이터가 주어졌을 때, 각 학생의 전체 평균 성적(수학, 영어, 과학)을 계산한 후, 이 평균값에 대한 분산과 표준편차를 구하세요.
#
#
# ```python
# # 학생별 과목 성적 데이터
# scores_math = [88, 92, 76, 85, 95, 92, 88, 90, 85, 88]
# scores_english = [90, 85, 80, 87, 92, 89, 83, 91, 86, 88]
# scores_science = [85, 88, 82, 89, 94, 86, 91, 88, 84, 87]
# ```

# %%
scores_math = [88, 92, 76, 85, 95, 92, 88, 90, 85, 88]
scores_english = [90, 85, 80, 87, 92, 89, 83, 91, 86, 88]
scores_science = [85, 88, 82, 89, 94, 86, 91, 88, 84, 87]

print(np.mean(scores_math + scores_english + scores_science))
print(np.var(scores_math + scores_english + scores_science))
print(np.std(scores_math + scores_english + scores_science))
# Out:
# 87.46666666666667
# 16.115555555555552
# 4.014418457953226
